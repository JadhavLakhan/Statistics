# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import skew

# %% [markdown]
# The probability mass function (PMF) of the binomial distribution is given by the formula:
#
# $$ P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k} $$

# %% [markdown]
# $$ \gamma_1 = \frac{1 - 2p}{\sqrt{np(1-p)}} $$

# %% [markdown]
# ## 1. Generate Binomial Data
# First, let’s generate some sample data that follows a binomial distribution.

# %%
# Parameters for the binomial distribution
n = 10 #trials
p = 0.5 #success

# Generate binomial data
data = np.random.binomial(n_trials, p_success, size=1000)

# %% [markdown]
# ## 2. Visualizing the Distribution
# Now, let's plot the histogram and the probability mass function to visualize the skewness.

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(data, bins=np.arange(-0.5, n + 1.5, 1), density=True, alpha=0.6, color='red', label='Histogram')
# Out:
# (array([0.001, 0.009, 0.042, 0.131, 0.2  , 0.247, 0.207, 0.111, 0.045,
#         0.007, 0.   ]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5,
#         10.5]),
#  <BarContainer object of 11 artists>)

# %%
# Calculate PMF for the binomial distribution
x = np.arange(0, n + 1)
pmf = stats.binom.pmf(x, n, p)
print(pmf)
# Out:
# [0.00097656 0.00976563 0.04394531 0.1171875  0.20507812 0.24609375
#  0.20507812 0.1171875  0.04394531 0.00976563 0.00097656]

# %%
# Plot PMF
plt.plot(x, pmf, 'ro', markersize=8, label='PMF', color='blue')
plt.plot(x, pmf, color='blue', linewidth=2)
plt.xlabel('X values')
plt.ylabel('PMF values')
plt.title('Probability Mass Function (PMF)')
plt.legend()
plt.grid()

# Show the plot
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_52920\1958084733.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, pmf, 'ro', markersize=8, label='PMF', color='blue')
